# %%
# %matplotlib notebook

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

batse = pd.read_csv('batse.csv', sep=',', header=0)

sns.set()

fig, ax = plt.subplots()
plt.title('Full Batse Data Set', fontsize = 16)
ax.set_xlabel('$T_{90}$', fontsize = 14)
ax.set_ylabel('$dN/dT_{90})$', fontsize = 14)
n, x, _ = plt.hist( batse['T90']
                  #, bins = np.exp(np.linspace(.1, 500, 39))
                  , histtype = u'step'
                  , density = False
                  )
plt.tight_layout()
plt.savefig("batse.t90.linear.linear.png")

fig, ax = plt.subplots()
plt.title('Full Batse Data Set', fontsize = 16)
ax.set_xscale('log')
ax.set_yscale('linear')
ax.set_xlabel('$T_{90}$', fontsize = 14)
ax.set_ylabel('$dN/dlog(T_{90})$', fontsize = 14)
n, x, _ = plt.hist(batse['T90'], bins=np.exp(np.linspace(np.log(.1), np.log(500), 39)), histtype=u'step', density=False)
plt.tight_layout()
plt.savefig("batse.logt90.log.linear.png")

fig, ax = plt.subplots()
plt.title('Full Batse Data Set', fontsize = 16)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$T_{90}$', fontsize = 14)
ax.set_ylabel('$dN/dlog(T_{90})$', fontsize = 14)
n, x, _ = plt.hist(batse['T90'], bins=np.exp(np.linspace(np.log(.1), np.log(500), 39)), histtype=u'step', density=False)
plt.tight_layout()
plt.savefig("batse.logt90.log.log.png")

fig,ax2=plt.subplots()
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('$T_{90}$', fontsize = 14)
ax2.set_ylabel('$dN/dT_{90}$', fontsize = 14)
bin_centers = 0.5*(x[1:]+x[:-1])
plt.step(bin_centers,np.divide(n,bin_centers))
plt.show()
plt.tight_layout()
plt.savefig("batse.t90.log.log.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
print("Skewness = ",batse['T90'].skew(axis=0,skipna=True))
# Out:
# Skewness =  6.4138413574014725

# %%
print("Kurtosis = ",batse['T90'].kurt(axis=0,skipna=True))
# Out:
# Kurtosis =  81.40306454529846

# %% [markdown]
# Read from Excel file

# %%
batse2 = pd.read_excel("Batse.xlsx", header=0)

# %%
batse2soft = pd.DataFrame(columns=["trg","f1","er1","f2","er2","f3","er3","f4","er4","f3_f2", \
        "T50","T50err","T50Start", "T90","T90err","T90Start"])

# %%
cond = batse2.f3_f2 < 2.6
rows = batse2.loc[cond,:]
batse2soft = batse2soft.append(rows, ignore_index=True, sort=False)

# %%
fig,ax=plt.subplots()
plt.title('Soft Batse Data Set', fontsize = 16)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$T_{90}$', fontsize = 14)
ax.set_ylabel('$dN/dlog(T_{90})$', fontsize = 14)
n, x, _ = plt.hist(batse2soft['T90'], bins=np.exp(np.linspace(np.log(.1), np.log(500), 39)), histtype=u'step', density=False)

fig,ax2=plt.subplots()
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('$T_{90}$', fontsize = 14)
ax2.set_ylabel('$dN/dT_{90}$', fontsize = 14)
bin_centers = 0.5*(x[1:]+x[:-1])
plt.step(bin_centers,np.divide(n,bin_centers))
plt.show()

# %%
print("Skewness = ",batse2soft['T90'].skew(axis=0,skipna=True))
# Out:
# Skewness =  3.20372052215307

# %%
print("Kurtosis = ",batse2soft['T90'].kurt(axis=0,skipna=True))
# Out:
# Kurtosis =  13.675095296545944
